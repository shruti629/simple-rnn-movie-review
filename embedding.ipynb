# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
#sentences
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good student',
    'your video is great',
    'learning is a continuous process',
    'I love deep learning'
]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good student',
#  'your video is great',
#  'learning is a continuous process',
#  'I love deep learning']

# %%
## Define vocabulary size
vocab_size = 10000

# %%
##one-hot  representation
one_hot_repr = [one_hot(words, vocab_size) for words in sent]

# %%
one_hot_repr
# Out:
# [[4648, 6921, 7898, 1171],
#  [4648, 6921, 7898, 7796],
#  [4648, 1088, 7898, 2166],
#  [5640, 5974, 2950, 1713, 624],
#  [7105, 8876, 96, 3488],
#  [2205, 96, 2950, 7719, 1411],
#  [5640, 4378, 2811, 2205]]

# %%
##word embedding representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 9
embedded_docs = pad_sequences(one_hot_repr, padding='pre', maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0    0 4648 6921 7898 1171]
#  [   0    0    0    0    0 4648 6921 7898 7796]
#  [   0    0    0    0    0 4648 1088 7898 2166]
#  [   0    0    0    0 5640 5974 2950 1713  624]
#  [   0    0    0    0    0 7105 8876   96 3488]
#  [   0    0    0    0 2205   96 2950 7719 1411]
#  [   0    0    0    0    0 5640 4378 2811 2205]]

# %%
#feature represtation
dim=10

# %%
model = Sequential()
model.add(Embedding(vocab_size, dim, input_length=sent_length))
model.compile(optimizer='adam', loss='mse')
# Out:
# e:\simple_rnn\venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.build(input_shape=(None, sent_length))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 9, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# array([[[-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [ 0.00040331, -0.01027023,  0.02988878,  0.04427706,
#          -0.04282284, -0.00615953,  0.04518409,  0.04567596,
#           0.04524298, -0.03566356],
#         [ 0.01661085,  0.0381675 , -0.00730287,  0.00267104,
#          -0.00635234, -0.01300859,  0.033624  , -0.00361945,
#           0.0038641 , -0.01282526],
#         [ 0.00162547, -0.00227131,  0.00601685,  0.04367448,
#          -0.03676482,  0.01403583,  0.00917774, -0.04676067,
#          -0.00459733, -0.04268972],
#         [ 0.04925149,  0.01431495, -0.04832379,  0.02047558,
#           0.0379725 , -0.04773874, -0.00770567,  0.01487196,
#           0.00942387,  0.02431643]],
#
#        [[-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [ 0.00040331, -0.01027023,  0.02988878,  0.04427706,
#          -0.04282284, -0.00615953,  0.04518409,  0.04567596,
#           0.04524298, -0.03566356],
#         [ 0.01661085,  0.0381675 , -0.00730287,  0.00267104,
#          -0.00635234, -0.01300859,  0.033624  , -0.00361945,
#           0.0038641 , -0.01282526],
#         [ 0.00162547, -0.00227131,  0.00601685,  0.04367448,
#          -0.03676482,  0.01403583,  0.00917774, -0.04676067,
#          -0.00459733, -0.04268972],
#         [-0.00567897,  0.04694927, -0.02782409,  0.01038486,
#           0.00345639, -0.02001511,  0.03917298, -0.0255672 ,
#          -0.01996471, -0.00595015]],
#
#        [[-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [ 0.00040331, -0.01027023,  0.02988878,  0.04427706,
#          -0.04282284, -0.00615953,  0.04518409,  0.04567596,
#           0.04524298, -0.03566356],
#         [ 0.04460821, -0.02345692,  0.00078138, -0.04447628,
#          -0.02554524,  0.00774967,  0.00280517, -0.01201984,
#           0.01604195,  0.04240198],
#         [ 0.00162547, -0.00227131,  0.00601685,  0.04367448,
#          -0.03676482,  0.01403583,  0.00917774, -0.04676067,
#          -0.00459733, -0.04268972],
#         [-0.03425578, -0.00072374, -0.02040227, -0.00492347,
#           0.01140988,  0.0393692 ,  0.02334572,  0.04411863,
#          -0.04897407,  0.00412712]],
#
#        [[-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [ 0.01258947, -0.04262535, -0.00846709, -0.00025789,
#           0.03836947, -0.00474051, -0.00955383, -0.00476643,
#          -0.04339487, -0.04330083],
#         [-0.04116108,  0.00843669, -0.02610052,  0.00770043,
#           0.03147367, -0.02835531,  0.01437953,  0.00227995,
#          -0.03523986,  0.01029011],
#         [ 0.01083164, -0.02796959, -0.03115408,  0.04431165,
#          -0.03328579, -0.02101871,  0.02814056, -0.00157552,
#          -0.02852233,  0.005009  ],
#         [-0.01016623,  0.02593337, -0.03758562, -0.04083697,
#           0.02943034,  0.02310604,  0.01341063, -0.0029787 ,
#           0.02098838,  0.03742733],
#         [ 0.00100021,  0.01753307, -0.04812291,  0.01733414,
#          -0.03304795,  0.04308397, -0.01575222,  0.00489327,
#          -0.02999672,  0.03146804]],
#
#        [[-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.04271786, -0.04184413,  0.02774702,  0.01768069,
#          -0.02930766, -0.01817055, -0.03522048,  0.03535264,
#          -0.03371654, -0.00997693],
#         [ 0.04026744,  0.0486348 ,  0.03288039, -0.04437921,
#          -0.04374378,  0.04925363, -0.00306513,  0.04923512,
#           0.03015388,  0.0159576 ],
#         [-0.00250969, -0.01868879,  0.03560224,  0.01650579,
#           0.02422322, -0.01936054, -0.00311353, -0.01675544,
#          -0.04002105,  0.01568973],
#         [-0.01075897, -0.04822644, -0.03109721,  0.03272055,
#           0.02806152,  0.03093566,  0.04148395, -0.03878039,
#          -0.02696198, -0.04700064]],
#
#        [[-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.04490108,  0.01407397,  0.00422436, -0.02118447,
#          -0.01742463,  0.02487779,  0.03045115,  0.01790622,
#           0.03684543,  0.01588894],
#         [-0.00250969, -0.01868879,  0.03560224,  0.01650579,
#           0.02422322, -0.01936054, -0.00311353, -0.01675544,
#          -0.04002105,  0.01568973],
#         [ 0.01083164, -0.02796959, -0.03115408,  0.04431165,
#          -0.03328579, -0.02101871,  0.02814056, -0.00157552,
#          -0.02852233,  0.005009  ],
#         [ 0.00987508,  0.02776727,  0.0262259 , -0.02011262,
#          -0.02425215, -0.02965777,  0.01310031, -0.00384219,
#           0.00733583,  0.0014119 ],
#         [ 0.00374841, -0.02398462,  0.04143906,  0.04856683,
#          -0.00554489, -0.01077492, -0.03184464, -0.01068296,
#           0.0259604 , -0.00351072]],
#
#        [[-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [-0.00545614, -0.02280885, -0.00591488, -0.01422372,
#          -0.03414863, -0.02777766,  0.01434226,  0.04577157,
#           0.0200665 ,  0.01557679],
#         [ 0.01258947, -0.04262535, -0.00846709, -0.00025789,
#           0.03836947, -0.00474051, -0.00955383, -0.00476643,
#          -0.04339487, -0.04330083],
#         [ 0.00334748,  0.00935736,  0.02977223, -0.03203968,
#           0.02308022, -0.01353325,  0.04381124, -0.00804472,
#           0.01160076,  0.01872248],
#         [-0.04149415,  0.0172937 ,  0.03205452,  0.03848118,
#           0.0213779 ,  0.03485839, -0.01838396, -0.03627525,
#          -0.04354309, -0.03805868],
#         [-0.04490108,  0.01407397,  0.00422436, -0.02118447,
#          -0.01742463,  0.02487779,  0.03045115,  0.01790622,
#           0.03684543,  0.01588894]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0,    0, 4648, 6921, 7898, 1171], dtype=int32)
